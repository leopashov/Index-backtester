# %%
import numpy as np
import pandas as pd
import yfinance as yf
import plotly.express as px

# %%
yf_prices = yf.download(['BTC-USD', 'ETH-USD'], start='2000-01-01')
prices = yf_prices['Adj Close']
fig1 = px.line(prices, title="eth-usd and btc-usd price history")
fig1.show()
# Out:
# [*********************100%***********************]  2 of 2 completed
#                Adj Close                      Close               \
#                  BTC-USD      ETH-USD       BTC-USD      ETH-USD
# Date
# 2014-09-17    457.334015          NaN    457.334015          NaN
# 2014-09-18    424.440002          NaN    424.440002          NaN
# 2014-09-19    394.795990          NaN    394.795990          NaN
# 2014-09-20    408.903992          NaN    408.903992          NaN
# 2014-09-21    398.821014          NaN    398.821014          NaN
# ...                  ...          ...           ...          ...
# 2022-12-03  16908.236328  1243.334839  16908.236328  1243.334839
# 2022-12-04  17130.486328  1280.256592  17130.486328  1280.256592
# 2022-12-05  16974.826172  1259.676758  16974.826172  1259.676758
# 2022-12-06  17089.503906  1271.653809  17089.503906  1271.653809
# 2022-12-07  16839.333984  1232.312988  16839.333984  1232.312988
#
# ...
